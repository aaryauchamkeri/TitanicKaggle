# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
titanic_data = pd.read_csv('train.csv')

# %%
# plt.scatter(titanic_data['age'], titanic_data['survived'])

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ndf = titanic_data.Age

# %%
ndf.fillna(29.69)
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
#        ...
# 886    27.00
# 887    19.00
# 888    29.69
# 889    26.00
# 890    32.00
# Name: Age, Length: 891, dtype: float64

# %%
ndf.columns = ['Age']

# %%
ndf.name
# Out:
# 'Age'

# %%
titanic_data.Age = ndf

# %%
res = titanic_data[titanic_data['Age'].isnull()]
res
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
ndf[ndf.isnull()]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64

# %%
ndf.fillna(29, inplace=True)

# %%
ndf[ndf.isnull()]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_data.Age = ndf

# %%
titanic_data[titanic_data['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.560236    0.523008
# std     257.353842    0.486592    0.836071   13.005010    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.fillna({'Age': 29}, inplace=True)

# %%
namecol = titanic_data['Name']

# %%
titanic_data.drop(['Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 titanic_data.drop(['Name'])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
plt.scatter(titanic_data['Age'], titanic_data['Survived'])

# %%
axs = plt.axes()

# %%
axs.set_xticks(np.arange(min(titanic_data['Age']), max(titanic_data['Age']), 5))

# %%
age_c = plt.scatter(titanic_data['Age'], titanic_data['Survived'])

# %%
age_c

# %%
age_c.axes.set_xticks(np.arange(min(titanic_data['Age']), max(titanic_data['Age']), 5))

# %%
plt.show()

# %%
plt.show(age_c)

# %%
plt.figure(figsize=(20, 6))
plt.axes().set_xticks(np.arange(min(titanic_data['Age']), max(titanic_data['Age']), 5))
plt.scatter(titanic_data['Age'], titanic_data['Survived'])

# %%
plt.figure(figsize=(20, 6))
plt.axes().set_xticks(np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50))
plt.scatter(titanic_data['Fare'], titanic_data['Survived'])
# Out:
#   Cell In[130], line 2
#     plt.axes().set_xticks(np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50))
#                          ^
# SyntaxError: '(' was never closed

# %%
titanic_data.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
titanic_data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic_data.iloc[titanic_data.loc[titanic_data['Name'] == 'Braund, Mr. Owen Harris'].index]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
titanic_data.drop(titanic_data.loc[titanic_data['Fare'] > 400].index, axis=0, inplace=True)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.loc[titanic_data['Fare'] > 400]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
plt.figure(figsize=(20, 6))
# np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50))
plt.axes().set_xticks(np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50)))
plt.scatter(titanic_data['Fare'], titanic_data['Survived'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6g/wjnwh0cd51vgnl0l7xmh2gm40000gp/T/ipykernel_16255/419741526.py in ?()
#       1 plt.figure(figsize=(20, 6))
#       2 # np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50))
# ----> 3 plt.axes().set_xticks(np.arange(min(titanic_data['Fare']), max(titanic_data['Fare'], 50)))
#       4 plt.scatter(titanic_data['Fare'], titanic_data['Survived'])
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ...

# %%
titanic_data.loc[titanic_data['Fare'] > 100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# 390          391         1       1
# ...

# %%
print(len(titanic_data))
titanic_data.drop(titanic_data.loc[titanic_data['Fare'] > 400].index, axis=0, inplace=True)
print(len(titanic_data))
# Out:
# 888
# 888

# %%
titanic_data.loc[titanic_data['PassengerId'] == 680]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
plt.figure(figsize=(30, 6))
plt.axes().set_xticks(np.arange(min(titanic_data['Fare']),max(titanic_data['Fare']),5))
plt.scatter(titanic_data['Fare'], titanic_data['Survived'])

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(titanic_data[['Fare','Survived']], x='Fare', y='Survived')
# Out:
# <Axes: xlabel='Fare', ylabel='Survived'>

# %%
titanic_data.columns
titanic_data['Sex'] = titanic_data['Sex'].apply(lambda x : '0' if x == 'male' else '1') 
# titanic_data.drop('Name', axis=1, inplace=True)
# sns.heatmap(titanic_data.corr(), color='YlGnBu')
# titanic_data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 4
#       2 titanic_data['Sex'] = titanic_data['Sex'].apply(lambda x : '0' if x == 'male' else '1')
#       3 # titanic_data.drop('Name', axis=1, inplace=True)
# ----> 4 sns.heatmap(titanic_data.corr(), color='YlGnBu')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
# ...

# %%
titanic_data.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.006916 -0.033005 -0.056929 -0.002223 -0.002046
# Survived       -0.006916  1.000000 -0.334068 -0.033395  0.082157  0.261742
# Pclass         -0.033005 -0.334068  1.000000  0.080937  0.018212 -0.604960
# SibSp          -0.056929 -0.033395  0.080937  1.000000  0.415141  0.211816
# Parch          -0.002223  0.082157  0.018212  0.415141  1.000000  0.263910
# Fare           -0.002046  0.261742 -0.604960  0.211816  0.263910  1.000000
# Age             0.036181 -0.079472 -0.368625 -0.307639 -0.189194  0.100396
#
#                   Age
# PassengerId  0.036181
# Survived    -0.079472
# Pclass      -0.368625
# SibSp       -0.307639
# Parch       -0.189194
# Fare         0.100396
# Age          1.000000

# %%
sns.heatmap(titanic_data.corr(numeric_only=True), cmap='YlGnBu')
# Out:
# <Axes: >

# %%
titanic_data.to_csv('workingdata.csv')

# %%
df = pd.read_csv('train.csv')

# %%
len(df)
# Out:
# 891

# %%
df.drop(df.loc[df['Fare'] > 400].index, axis=0,inplace=True)

# %%
len(df)
# Out:
# 888

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='YlGnBu')
# Out:
# <Axes: >

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 888, dtype: object

# %%
temp = df['Sex']

# %%
temp
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 888, dtype: object

# %%
temp = temp.apply(lambda x : '0' if x == 'male' else x)

# %%
temp
# Out:
# 0           0
# 1      female
# 2      female
# 3      female
# 4           0
#         ...
# 886         0
# 887    female
# 888    female
# 889         0
# 890         0
# Name: Sex, Length: 888, dtype: object

# %%
temp = temp.apply(lambda x : '1' if x == 'female' else x)

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
temp = temp.astype('int64')
# temp

# %%
df['Sex'] = temp

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='YlGnBu')
# Out:
# <Axes: >

# %%
df[['Sex','Survived']].loc[df['Sex'] == 0].describe()
# Out:
#          Sex    Survived
# count  575.0  575.000000
# mean     0.0    0.186087
# std      0.0    0.389516
# min      0.0    0.000000
# 25%      0.0    0.000000
# 50%      0.0    0.000000
# 75%      0.0    0.000000
# max      0.0    1.000000

# %%
maleFare = df['Fare'].loc[df['Sex'] == 0]
maleSurvive = df['Survived'].loc[df['Sex'] == 0]
plt.figure(figsize=(20, 6))
plt.axes().set_xticks(np.arange(min(titanic_data['Fare']), max(titanic_data['Fare']), 25))
plt.scatter(maleFare, maleSurvive)

# %%
sns.heatmap(
    , cmap='YlGnBu')
# Out:
# <Axes: >

# %%
df.loc[df['Sex'] == 0].corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass  Sex       Age     SibSp  \
# PassengerId     1.000000  0.033648  0.008284  NaN  0.004790 -0.083657
# Survived        0.033648  1.000000 -0.210943  NaN -0.123552 -0.017454
# Pclass          0.008284 -0.210943  1.000000  NaN -0.392819  0.074951
# Sex                  NaN       NaN       NaN  NaN       NaN       NaN
# Age             0.004790 -0.123552 -0.392819  NaN  1.000000 -0.334543
# SibSp          -0.083657 -0.017454  0.074951  NaN -0.334543  1.000000
# Parch          -0.086426  0.094048 -0.029103  NaN -0.233467  0.526389
# Fare           -0.065133  0.121424 -0.546163  NaN  0.087546  0.265170
#
#                 Parch      Fare
# PassengerId -0.086426 -0.065133
# Survived     0.094048  0.121424
# Pclass      -0.029103 -0.546163
# Sex               NaN       NaN
# Age         -0.233467  0.087546
# SibSp        0.526389  0.265170
# Parch        1.000000  0.396413
# Fare         0.396413  1.000000

# %%
maledf = df.loc[df['Sex'] == 0]
femaledf = df.loc[df['Sex'] == 1]

# %%
maledf
# Out:
#      PassengerId  Survived  Pclass                            Name  Sex   Age  \
# 0              1         0       3         Braund, Mr. Owen Harris    0  22.0
# 4              5         0       3        Allen, Mr. William Henry    0  35.0
# 5              6         0       3                Moran, Mr. James    0   NaN
# 6              7         0       1         McCarthy, Mr. Timothy J    0  54.0
# 7              8         0       3  Palsson, Master. Gosta Leonard    0   2.0
# ..           ...       ...     ...                             ...  ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James    0  28.0
# 884          885         0       3          Sutehall, Mr. Henry Jr    0  25.0
# 886          887         0       2           Montvila, Rev. Juozas    0  27.0
# 889          890         1       1           Behr, Mr. Karl Howell    0  26.0
# 890          891         0       3             Dooley, Mr. Patrick    0  32.0
#
# ...

# %%
femaledf
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
plt.scatter(maledf['Pclass'], maledf['Survived'])

# %%
survived = {1:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 1], 2:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 2], 3:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 3]}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6g/wjnwh0cd51vgnl0l7xmh2gm40000gp/T/ipykernel_16255/1658439554.py in ?()
# ----> 1 survived = {1:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 1], 2:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 2], 3:maledf.loc[maledf['Survived'] == 1 and maledf['Pclass'] == 3]}
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  888 non-null    int64
#  1   Survived     888 non-null    int64
#  2   Pclass       888 non-null    int64
#  3   Name         888 non-null    object
#  4   Sex          888 non-null    int64
#  5   Age          711 non-null    float64
#  6   SibSp        888 non-null    int64
#  7   Parch        888 non-null    int64
#  8   Ticket       888 non-null    object
#  9   Fare         888 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     886 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 90.2+ KB
